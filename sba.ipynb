# %%
# !nvidia-smi
# Out:
# Thu May 16 10:31:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.9/756.9 kB 7.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install kaggle

# %%
# !mkdir /.kaggle
# !mv kaggle.json /.kaggle
# !mv /.kaggle /root/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d mehmetcubukcu/weapon-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mehmetcubukcu/weapon-detection
# License(s): CC-BY-SA-4.0
# ...
#  99% 1.70G/1.71G [00:19<00:00, 45.8MB/s]
# 100% 1.71G/1.71G [00:19<00:00, 92.6MB/s]

# %%
# !unzip weapon-detection.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: weapon-detection/train/labels/billete_2016.txt
#   inflating: weapon-detection/train/labels/billete_2017.txt
#   inflating: weapon-detection/train/labels/billete_2018.txt
#   inflating: weapon-detection/train/labels/billete_2019.txt
#   inflating: weapon-detection/train/labels/billete_2020.txt
#   inflating: weapon-detection/train/labels/billete_2021.txt
#   inflating: weapon-detection/train/labels/billete_2022.txt
#   inflating: weapon-detection/train/labels/billete_2023.txt
#   inflating: weapon-detection/train/labels/billete_2024.txt
#   inflating: weapon-detection/train/labels/billete_2025.txt
#   inflating: weapon-detection/train/labels/billete_2026.txt
#   inflating: weapon-detection/train/labels/billete_2027.txt
#   inflating: weapon-detection/train/labels/billete_2028.txt
#   inflating: weapon-detection/train/labels/billete_2029.txt
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="/content/weapon-detection/data.yaml", epochs=30,project="./", name="train")
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
